# %%
import os
import re
import pandas as pd
import math
import pywt
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, ZeroPadding2D, Conv2D, Conv2DTranspose, Activation, Dense, Activation, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping
import itertools
from tensorflow.keras.utils import to_categorical
from datetime import datetime

# %%
image_path = r"Serial/Sent/Data/"
excel_file = r"Serial/Sent/labels.xlsx"
labels_df = pd.read_excel(excel_file)

labels_df['label'] = labels_df['label'].fillna('').astype(str)
valid_labels_df = labels_df[labels_df['label'].str.match(r'^[A-Za-z0-9]{9}$')]
labels = list(valid_labels_df['label'])
image_names = valid_labels_df["image_name"]
print(f"Rows removed: {len(labels_df) - len(valid_labels_df)}")
# Out:
# Rows removed: 13

# %%
images_list = []
image_paths = []


def Read_images(image_path, image_names):
    for image_name in image_names:
        img_path = os.path.join(image_path, image_name)
        if os.path.isfile(img_path):
            img = cv2.imread(img_path)
            if img is not None:
                images_list.append(img)
            else:
                print(f"Error reading image: {img_path}")

Read_images(image_path, image_names)


X_train_val, X_test, y_train_val, y_test = train_test_split(images_list, labels, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=42)
print(f"Training set size: {len(X_train)}")
print(f"Validation set size: {len(X_val)}")
print(f"Test set size: {len(X_test)}")
# Out:
# Training set size: 1088
# Validation set size: 272
# Test set size: 340

# %%
#Pre-processing

def estimate_noise_std(image):
    coeffs = pywt.dwt2(image, wavelet='db1')
    _, (cH, cV, cD) = coeffs  
    detail_coeffs = np.concatenate([cH.ravel(), cV.ravel(), cD.ravel()])
    mad = np.median(np.abs(detail_coeffs - np.median(detail_coeffs)))
    noise_std = mad / 0.6745
    return noise_std

def wavelet_denoising(img, wavelet='db1', level=2, threshold_value=20):
    coeffs = pywt.wavedec2(img, wavelet=wavelet, level=level)
    cA, (cH, cV, cD) = coeffs[0], coeffs[1]

    def thresholding(coeff, threshold):
        return pywt.threshold(coeff, threshold, mode='soft')

    cH = thresholding(cH, threshold_value)
    cV = thresholding(cV, threshold_value)
    cD = thresholding(cD, threshold_value)
    coeffs[1] = (cH, cV, cD)
    denoised_img = pywt.waverec2(coeffs, wavelet=wavelet)
    denoised_img = np.clip(denoised_img, 0, 255).astype(np.uint8)

    return denoised_img

def find_and_sort_contours(img, min_area, block_size=39, C=15, wavelet_mode='db1'):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    noise_std = estimate_noise_std(img)
    threshold_value = noise_std * np.sqrt(2.25 * np.log(img.size))
    img = wavelet_denoising(img, wavelet=wavelet_mode, level=4, threshold_value=threshold_value)
    img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, block_size, C)
    
    num_labels, labels = cv2.connectedComponents(img)
    valid_contours = []
    for i in range(1, num_labels):  
        component_mask = (labels == i).astype(np.uint8) * 255
        component_contours, _ = cv2.findContours(component_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        if len(component_contours) == 1: 
            contour = component_contours[0]
            area = cv2.contourArea(contour)
            x, y, w, h = cv2.boundingRect(contour)
            aspect_ratio = float(w) / h

            if min_area <= area and 0.2 < aspect_ratio < 1.3: 
                valid_contours.append(contour)

    valid_contours = sorted(valid_contours, key=lambda contour: cv2.boundingRect(contour)[0])
    return valid_contours, len(valid_contours)

# %%
# Hyperparameters
wavelet_types = ['db1', 'sym4']
threshold_modes = ['soft', 'hard']
levels = [3, 4]
adaptive_threshold_types = [cv2.ADAPTIVE_THRESH_GAUSSIAN_C]
C_values = range(10, 21, 2)  
block_sizes = range(35, 47, 2)

wavelet_types = ['db1', 'sym4']
threshold_modes = ['soft']
levels = [3, 4]
adaptive_threshold_types = [cv2.ADAPTIVE_THRESH_GAUSSIAN_C]
C_values = range(15, 19, 2)
block_sizes = range(39, 45, 2)

param_combinations = list(itertools.product(wavelet_types, threshold_modes, levels, adaptive_threshold_types, C_values, block_sizes))

def evaluate_parameters(wavelet, mode, level, adaptive_thresh_type, C_value, block_size, img):
    noise_std = estimate_noise_std(img)
    threshold_value = noise_std * np.sqrt(2.25 * np.log(img.size))
    img_denoised = wavelet_denoising(img, wavelet=wavelet, level=level, threshold_value=threshold_value)
    img_thresholded = cv2.adaptiveThreshold(img_denoised, 255, adaptive_thresh_type, cv2.THRESH_BINARY_INV, block_size, C_value)
    valid_contours, valid_contour_count = find_and_sort_contours(img_thresholded, min_area=9)
    return valid_contour_count


def grid_search(param_combinations, images):
    successful_combinations = {comb: 0 for comb in param_combinations}
    
    total_combinations = len(param_combinations) * len(images)
    current_progress = 0
    
    for params in param_combinations:
        wavelet, mode, level, adaptive_thresh_type, C_value, block_size = params
        for idx, img in enumerate(images):
            current_progress += 1
            print(f"Testing hyperparameters: {params} | Progress: {current_progress}/{total_combinations}")
            
            if len(img.shape) == 3:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            valid_contour_count = evaluate_parameters(wavelet, mode, level, adaptive_thresh_type, C_value, block_size, img)
            if valid_contour_count == 9:
                successful_combinations[params] += 1
    
    best_combination = max(successful_combinations, key=successful_combinations.get)
    best_count = successful_combinations[best_combination]
    return best_combination, best_count

# Running grid search
#best_combination, best_count = grid_search(param_combinations, X_train)
#print(f"Best parameter combination: {best_combination} with {best_count} successful detections of exactly 9 contours")
# Best parameter combination: ('db1', 'soft', 4, 1, 15, 39) with 0 successful detections of exactly 9 contours

# %%
# Encode and evaluate
def evaluate_contours(images, labels, print_text):
    imgs = []
    invalid_indexes_and_labels = []  
    for idx, (img, label) in enumerate(zip(images, labels)):
        valid_contours, valid_contour_count = find_and_sort_contours(img, 9)      
        if valid_contour_count == 9:
            imgs.append(img)
            invalid_indexes_and_labels.append((idx, label, valid_contour_count)) 
    print(f"Number of images with valid contour count not equal to 9 for {print_text}: {len(imgs)} / {len(images)} = {(len(imgs) / len(images))*100:.2f}%")
    return imgs, invalid_indexes_and_labels, imgs

valid_idx_train = []
valid_contours_list_train = []
valid_idx_val = []
valid_contours_list_val = []
valid_idx_test = []
valid_contours_list_test = []

def Segment_chars(images, valid_idx, valid_contours_list):
    for idx, img in enumerate(images):  
        valid_contours, valid_contour_count = find_and_sort_contours(img, 9)      
        if valid_contour_count == 9:
            valid_idx.append(idx)
            valid_contours_list.append(np.array(valid_contours, dtype=object))

Segment_chars(X_train, valid_idx_train, valid_contours_list_train)
Segment_chars(X_val, valid_idx_val, valid_contours_list_val)
Segment_chars(X_test, valid_idx_test, valid_contours_list_test)



def Encode_labels(labels):
    result = []  
    for label in labels:
        char_list = []
        for c in label:
            if '0' <= c <= '9':
                char_list.append(ord(c) - ord('0'))
            elif 'A' <= c <= 'Z':
                char_list.append(ord(c) - ord('A') + 10)
            else:
                print(f"Invalid character detected in label: {label}")     
        result.append(np.array(char_list))  
    return result

Encoded_labels_train = Encode_labels([y_train[i] for i in valid_idx_train])
Encoded_labels_val = Encode_labels([y_val[i] for i in valid_idx_val])
Encoded_labels_test = Encode_labels([y_test[i] for i in valid_idx_test])


for i in range(min(1, len(valid_idx_train))):
    print(f"-Label: {y_train[valid_idx_train[i]]} || -Encoding: {Encoded_labels_train[i]}")

test = ['09AZ']
print(f"Label: {test} || -Encoding: {Encode_labels(test)}")
# Out:
# -Label: IE8977447 || -Encoding: [18 14  8  9  7  7  4  4  7]
# Label: ['09AZ'] || -Encoding: [array([ 0,  9, 10, 35])]

# %%
def plot_images_with_invalid_contours(X_data, y_data, invalid_info, imgs, title="", num_images_to_display=32, cols=8):
    indices = [info[0] for info in invalid_info]
    num_images = len(indices)
    rows = math.ceil(num_images / cols)
    
    plt.figure(figsize=(cols * 2, rows + 1)) 
    for i, idx in enumerate(indices[:num_images_to_display]):
        img = X_data[idx]
        img = imgs[i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
        
        noise_std = estimate_noise_std(img)    
        threshold_value = noise_std * np.sqrt(2.25 * np.log(img.size))
        img = wavelet_denoising(img, wavelet='db1', level=4, threshold_value=threshold_value)
        img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 39, 15)
        
        name = y_data[idx]
        plt.subplot(rows, cols, i + 1)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(f"{invalid_info[i][2]}C \n {name} \n ({idx})") 
    
    plt.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

# Example usage for training data:
imgs_with_invalid_contours, invalid_info_train, imgs_train = evaluate_contours(X_train, y_train, 'train set')
plot_images_with_invalid_contours(X_train, y_train, invalid_info_train, imgs_train)

# Example usage for validation data:
imgs_with_invalid_contours, invalid_info_val, imgs_val = evaluate_contours(X_val, y_val, 'validation set')
plot_images_with_invalid_contours(X_val, y_val, invalid_info_val, imgs_val)

# Example usage for test data:
imgs_with_invalid_contours, invalid_info_test, imgs_test = evaluate_contours(X_test, y_test, 'test set')
plot_images_with_invalid_contours(X_test, y_test, invalid_info_test, imgs_test)
# Out:
# Number of images with valid contour count not equal to 9 for train set: 32 / 1088 = 2.94%
# Number of images with valid contour count not equal to 9 for validation set: 12 / 272 = 4.41%
# Number of images with valid contour count not equal to 9 for test set: 10 / 340 = 2.94%

# %%
def plot_images_with_contours(images_list, valid_idx, labels, valid_contours_list, Encoded_labels, cols=9, max_images=100, sub_image_size=(30, 30)):
    num_images = min(len(valid_idx), max_images)  
    rows = math.ceil(num_images / cols)  
    plt.figure(figsize=(cols * 1.5, rows * 1.5))  
    subplot_idx = 1  
    
    for i, idx in enumerate(valid_idx[:num_images]):  
        img = images_list[idx]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
        name = labels[idx]
        
        sub_images = []
        for contour in valid_contours_list[i]:
            x, y, w, h = cv2.boundingRect(contour)  
            if w > 0 and h > 0:  
                sub_image = img[y:y+h, x:x+w]  
                sub_image = cv2.resize(sub_image, sub_image_size) 
                sub_images.append(sub_image)

        for sub_image in sub_images:
            if subplot_idx > rows * cols:  
                break
            plt.subplot(rows, cols, subplot_idx)
            plt.imshow(sub_image, cmap='gray')
            plt.axis('off')
            subplot_idx += 1
        
        if subplot_idx <= rows * cols:
            plt.subplot(rows, cols, subplot_idx - len(sub_images))
            plt.title(f"{i+1}. {name}\n{Encoded_labels[i]}", fontsize=6, pad=2)
            plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage:
plot_images_with_contours(X_train, valid_idx_train, y_train, valid_contours_list_train, Encoded_labels_train, cols=9, max_images=20)

# %%
def save_segmented_chars(images_list, valid_idx, labels, valid_contours_list, Encoded_labels, save_path):
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    for i, idx in enumerate(valid_idx):
        img = images_list[idx]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        image_label = labels[idx]
        encoded_label = Encoded_labels[i]
        
        image_folder = os.path.join(save_path, f"image_{idx}_{image_label}")
        if not os.path.exists(image_folder):
            os.makedirs(image_folder)
        
        sorted_contours_with_boxes = sorted(
            [(contour, cv2.boundingRect(contour)) for contour in valid_contours_list[i]],
            key=lambda item: item[1][0]
        )
        
        for char_idx, (contour, (x, y, w, h)) in enumerate(sorted_contours_with_boxes):
            if w > 0 and h > 0:
                char_image = img[y:y+h, x:x+w]
                char_image_resized = cv2.resize(char_image, (30, 30))
                
                char = chr(encoded_label[char_idx] + ord('0')) if encoded_label[char_idx] < 10 else chr(encoded_label[char_idx] - 10 + ord('A'))
                
                char_filename = os.path.join(image_folder, f"{char_idx + 1}_{char}.jpg")
                cv2.imwrite(char_filename, char_image_resized)

        print(f"Saved segmented characters for image {idx} with label '{image_label}'")

save_path = "segmented_chars/train"  
save_segmented_chars(X_train, valid_idx_train, y_train, valid_contours_list_train, Encoded_labels_train, save_path)

save_path = "segmented_chars/val"  
save_segmented_chars(X_val, valid_idx_val, y_val, valid_contours_list_val, Encoded_labels_val, save_path)

save_path = "segmented_chars/test"  
save_segmented_chars(X_test, valid_idx_test, y_test, valid_contours_list_test, Encoded_labels_test, save_path)
# Out:
# Saved segmented characters for image 0 with label 'IE8977447'
# Saved segmented characters for image 1 with label 'IV3119250'
# Saved segmented characters for image 2 with label 'GL4020160'
# Saved segmented characters for image 3 with label 'GJ4996876'
# Saved segmented characters for image 4 with label 'HQ0685914'
# Saved segmented characters for image 5 with label 'JD3425363'
# Saved segmented characters for image 6 with label 'IF0010428'
# Saved segmented characters for image 7 with label 'IZ0783382'
# Saved segmented characters for image 8 with label 'JF0847016'
# Saved segmented characters for image 9 with label 'IT9391975'
# Saved segmented characters for image 10 with label 'IS5029974'
# Saved segmented characters for image 11 with label 'HG6744448'
# Saved segmented characters for image 12 with label 'II9284030'
# Saved segmented characters for image 13 with label 'JE2388181'
# Saved segmented characters for image 14 with label 'IG9302297'
# Saved segmented characters for image 15 with label 'HD4047946'
# Saved segmented characters for image 16 with label 'IE8850492'
# Saved segmented characters for image 17 with label 'GY7040087'
# Saved segmented characters for image 18 with label 'HX4863465'
# Saved segmented characters for image 19 with label 'JC4919011'
# Saved segmented characters for image 20 with label 'IF3367864'
# Saved segmented characters for image 21 with label 'GI3690600'
# Saved segmented characters for image 22 with label 'JB8315841'
# Saved segmented characters for image 23 with label 'JJ2278827'
# Saved segmented characters for image 24 with label 'HL1139600'
# Saved segmented characters for image 25 with label 'JD1135415'
# Saved segmented characters for image 26 with label 'JD1600131'
# Saved segmented characters for image 27 with label 'HQ7945185'
# Saved segmented characters for image 28 with label 'HH2522542'
# Saved segmented characters for image 29 with label 'IH7207830'
# Saved segmented characters for image 30 with label 'JE8921184'
# Saved segmented characters for image 31 with label 'GM8473639'
# Saved segmented characters for image 32 with label 'JD4759339'
# Saved segmented characters for image 33 with label 'GZ6610105'
# Saved segmented characters for image 34 with label 'IJ4498327'
# Saved segmented characters for image 35 with label 'HL1930490'
# Saved segmented characters for image 36 with label 'IN2501948'
# Saved segmented characters for image 37 with label 'IU6540724'
# Saved segmented characters for image 38 with label 'GH9139227'
# Saved segmented characters for image 39 with label 'HR5913570'
# Saved segmented characters for image 40 with label 'HN6094270'
# Saved segmented characters for image 41 with label 'IP0686103'
# Saved segmented characters for image 42 with label 'IC1477478'
# Saved segmented characters for image 43 with label 'JF6911849'
# Saved segmented characters for image 44 with label 'GZ7014771'
# Saved segmented characters for image 45 with label 'HU1105028'
# Saved segmented characters for image 46 with label 'JP2065980'
# Saved segmented characters for image 47 with label 'JJ6912208'
# Saved segmented characters for image 48 with label 'HA1067173'
# Saved segmented characters for image 49 with label 'IQ6540034'
# Saved segmented characters for image 50 with label 'IX6139006'
# Saved segmented characters for image 51 with label 'JG2299692'
# Saved segmented characters for image 52 with label 'IK9309762'
# Saved segmented characters for image 53 with label 'GS8681755'
# Saved segmented characters for image 54 with label 'HI0852404'
# Saved segmented characters for image 55 with label 'HK6676606'
# Saved segmented characters for image 56 with label 'IS0987538'
# Saved segmented characters for image 57 with label 'HY5981334'
# Saved segmented characters for image 58 with label 'IK6695459'
# Saved segmented characters for image 59 with label 'JI5886231'
# Saved segmented characters for image 60 with label 'IP4756416'
# Saved segmented characters for image 61 with label 'JD3937004'
# Saved segmented characters for image 62 with label 'IN1896306'
# Saved segmented characters for image 63 with label 'IS7907049'
# Saved segmented characters for image 64 with label 'HP3007169'
# Saved segmented characters for image 65 with label 'HL1209365'
# Saved segmented characters for image 66 with label 'HB2327121'
# Saved segmented characters for image 67 with label 'IF2685800'
# Saved segmented characters for image 68 with label 'IF8209413'
# Saved segmented characters for image 69 with label 'IP7135562'
# Saved segmented characters for image 70 with label 'HD8074991'
# Saved segmented characters for image 71 with label 'HR5913570'
# Saved segmented characters for image 72 with label 'ID1342140'
# Saved segmented characters for image 73 with label 'HY2584161'
# Saved segmented characters for image 74 with label 'HE7263715'
# Saved segmented characters for image 75 with label 'IP5542649'
# Saved segmented characters for image 76 with label 'GH9139227'
# Saved segmented characters for image 77 with label 'GR4095041'
# Saved segmented characters for image 78 with label 'HA5259785'
# Saved segmented characters for image 79 with label 'GS3167548'
# Saved segmented characters for image 80 with label 'IY5336928'
# Saved segmented characters for image 81 with label 'HQ3953632'
# Saved segmented characters for image 82 with label 'HF2268530'
# Saved segmented characters for image 83 with label 'GI3126338'
# Saved segmented characters for image 84 with label 'HZ1539574'
# Saved segmented characters for image 85 with label 'GT4638578'
# Saved segmented characters for image 86 with label 'IP5650430'
# Saved segmented characters for image 87 with label 'IX6088294'
# Saved segmented characters for image 88 with label 'IY0046268'
# Saved segmented characters for image 89 with label 'GV0503524'
# Saved segmented characters for image 90 with label 'IT0909814'
# Saved segmented characters for image 91 with label 'JC4669248'
# Saved segmented characters for image 92 with label 'IQ2967350'
# Saved segmented characters for image 93 with label 'IQ2641768'
# Saved segmented characters for image 94 with label 'GU7262401'
# Saved segmented characters for image 95 with label 'JB6335939'
# Saved segmented characters for image 96 with label 'IL0186103'
# Saved segmented characters for image 97 with label 'HY7059206'
# Saved segmented characters for image 98 with label 'HO4831496'
# Saved segmented characters for image 99 with label 'GK5240812'
# Saved segmented characters for image 100 with label 'IH5354743'
# Saved segmented characters for image 101 with label 'IR8312289'
# Saved segmented characters for image 102 with label 'IG3625495'
# Saved segmented characters for image 103 with label 'IP9455053'
# Saved segmented characters for image 104 with label 'IQ0432472'
# Saved segmented characters for image 105 with label 'IM7269974'
# Saved segmented characters for image 106 with label 'GG6973906'
# Saved segmented characters for image 107 with label 'II2636106'
# Saved segmented characters for image 108 with label 'HE0257272'
# Saved segmented characters for image 109 with label 'IQ0432472'
# Saved segmented characters for image 110 with label 'JC4669248'
# Saved segmented characters for image 111 with label 'HM1181066'
# Saved segmented characters for image 112 with label 'II5181269'
# Saved segmented characters for image 113 with label 'IT9391975'
# Saved segmented characters for image 114 with label 'GY4131461'
# Saved segmented characters for image 115 with label 'IM7420281'
# Saved segmented characters for image 116 with label 'IQ1355501'
# Saved segmented characters for image 117 with label 'IU0210964'
# Saved segmented characters for image 118 with label 'IT1980506'
# Saved segmented characters for image 119 with label 'IT8904765'
# Saved segmented characters for image 120 with label 'IW3352760'
# Saved segmented characters for image 121 with label 'GT4829981'
# Saved segmented characters for image 122 with label 'IJ4675801'
# Saved segmented characters for image 123 with label 'ID8187687'
# Saved segmented characters for image 124 with label 'HN1648098'
# Saved segmented characters for image 125 with label 'GO4819831'
# Saved segmented characters for image 126 with label 'GJ7208370'
# Saved segmented characters for image 127 with label 'GQ2538363'
# Saved segmented characters for image 128 with label 'JE0605086'
# Saved segmented characters for image 129 with label 'IC1678855'
# Saved segmented characters for image 130 with label 'IY5336928'
# Saved segmented characters for image 131 with label 'GV8956104'
# Saved segmented characters for image 132 with label 'GR4372959'
# Saved segmented characters for image 133 with label 'HI6447909'
# Saved segmented characters for image 134 with label 'HS0706079'
# Saved segmented characters for image 135 with label 'IQ7314148'
# Saved segmented characters for image 136 with label 'IW3404599'
# Saved segmented characters for image 137 with label 'IK3717299'
# Saved segmented characters for image 138 with label 'HX9306787'
# Saved segmented characters for image 139 with label 'IF6066140'
# Saved segmented characters for image 140 with label 'HL1721711'
# Saved segmented characters for image 141 with label 'JI2789506'
# Saved segmented characters for image 142 with label 'JI7264877'
# Saved segmented characters for image 143 with label 'IW5978782'
# Saved segmented characters for image 144 with label 'IH7122054'
# Saved segmented characters for image 145 with label 'IL5275240'
# Saved segmented characters for image 146 with label 'IF8726851'
# Saved segmented characters for image 147 with label 'HT8386416'
# Saved segmented characters for image 148 with label 'IC1678855'
# Saved segmented characters for image 149 with label 'GS2282367'
# Saved segmented characters for image 150 with label 'HO5310495'
# Saved segmented characters for image 151 with label 'HW5621148'
# Saved segmented characters for image 152 with label 'IK3406838'
# Saved segmented characters for image 154 with label 'HU5783204'
# Saved segmented characters for image 155 with label 'IQ2940674'
# Saved segmented characters for image 156 with label 'HZ5014459'
# Saved segmented characters for image 157 with label 'GQ3403758'
# Saved segmented characters for image 158 with label 'IM7251711'
# Saved segmented characters for image 159 with label 'IL3983109'
# Saved segmented characters for image 160 with label 'GU6781565'
# Saved segmented characters for image 161 with label 'GR4234703'
# Saved segmented characters for image 162 with label 'HK3513663'
# Saved segmented characters for image 163 with label 'JI0029154'
# Saved segmented characters for image 164 with label 'HP0932574'
# Saved segmented characters for image 166 with label 'IF8726851'
# Saved segmented characters for image 167 with label 'II9284218'
# Saved segmented characters for image 168 with label 'IN1682952'
# Saved segmented characters for image 169 with label 'JJ6530424'
# Saved segmented characters for image 170 with label 'HN6060882'
# Saved segmented characters for image 171 with label 'IF8146363'
# Saved segmented characters for image 172 with label 'HW5378408'
# Saved segmented characters for image 173 with label 'HD2275301'
# Saved segmented characters for image 174 with label 'IT6046573'
# Saved segmented characters for image 175 with label 'JL3909881'
# Saved segmented characters for image 176 with label 'GX3530723'
# Saved segmented characters for image 177 with label 'IN8451780'
# Saved segmented characters for image 178 with label 'IU5459498'
# Saved segmented characters for image 179 with label 'HT1660489'
# Saved segmented characters for image 180 with label 'JF6960568'
# Saved segmented characters for image 181 with label 'JO7007915'
# Saved segmented characters for image 182 with label 'IF8265763'
# Saved segmented characters for image 183 with label 'IR2473904'
# Saved segmented characters for image 184 with label 'IH7148108'
# Saved segmented characters for image 185 with label 'HK6676606'
# Saved segmented characters for image 187 with label 'HX9418226'
# Saved segmented characters for image 188 with label 'IH0393451'
# Saved segmented characters for image 189 with label 'HG6026199'
# Saved segmented characters for image 190 with label 'IF8000724'
# Saved segmented characters for image 191 with label 'GR4276040'
# Saved segmented characters for image 192 with label 'GP3579018'
# Saved segmented characters for image 193 with label 'JG4217245'
# Saved segmented characters for image 194 with label 'IO4398998'
# Saved segmented characters for image 195 with label 'IY2818926'
# Saved segmented characters for image 196 with label 'JA3011479'
# Saved segmented characters for image 197 with label 'JA0978306'
# Saved segmented characters for image 198 with label 'JE1343358'
# Saved segmented characters for image 199 with label 'IE1477649'
# Saved segmented characters for image 200 with label 'GR7988827'
# Saved segmented characters for image 201 with label 'HO5955669'
# Saved segmented characters for image 202 with label 'HZ6580753'
# Saved segmented characters for image 203 with label 'JH1399390'
# Saved segmented characters for image 204 with label 'IE9243417'
# Saved segmented characters for image 205 with label 'HY7265034'
# Saved segmented characters for image 206 with label 'IH6819603'
# Saved segmented characters for image 207 with label 'II8607803'
# Saved segmented characters for image 208 with label 'JK7316851'
# Saved segmented characters for image 209 with label 'GY4131461'
# Saved segmented characters for image 210 with label 'HJ8516422'
# Saved segmented characters for image 211 with label 'HI5902786'
# Saved segmented characters for image 212 with label 'HY7395218'
# Saved segmented characters for image 213 with label 'JI3378233'
# Saved segmented characters for image 214 with label 'HY5323161'
# Saved segmented characters for image 215 with label 'IV0494024'
# Saved segmented characters for image 216 with label 'ID5595913'
# Saved segmented characters for image 217 with label 'IM4664246'
# Saved segmented characters for image 218 with label 'JH2641454'
# Saved segmented characters for image 219 with label 'HQ7974963'
# Saved segmented characters for image 220 with label 'IA0958345'
# Saved segmented characters for image 221 with label 'JM2172548'
# Saved segmented characters for image 222 with label 'IP9458603'
# Saved segmented characters for image 223 with label 'GF2881372'
# Saved segmented characters for image 224 with label 'IZ0783382'
# Saved segmented characters for image 225 with label 'HS1141622'
# Saved segmented characters for image 226 with label 'HP7403264'
# Saved segmented characters for image 227 with label 'HX2055958'
# Saved segmented characters for image 228 with label 'IO7777439'
# Saved segmented characters for image 229 with label 'FZ4349022'
# Saved segmented characters for image 230 with label 'JL2107581'
# Saved segmented characters for image 231 with label 'HZ5014459'
# Saved segmented characters for image 232 with label 'HH5179507'
# Saved segmented characters for image 233 with label 'IJ4051045'
# Saved segmented characters for image 234 with label 'IM4439109'
# Saved segmented characters for image 235 with label 'GA1819483'
# Saved segmented characters for image 236 with label 'IS1065541'
# Saved segmented characters for image 237 with label 'JE0932465'
# Saved segmented characters for image 238 with label 'ID9040200'
# Saved segmented characters for image 239 with label 'HZ4912310'
# Saved segmented characters for image 241 with label 'JO7418454'
# Saved segmented characters for image 242 with label 'GZ1857381'
# Saved segmented characters for image 243 with label 'JI6919367'
# Saved segmented characters for image 244 with label 'JP3837663'
# Saved segmented characters for image 245 with label 'ID1712835'
# Saved segmented characters for image 246 with label 'HZ3083871'
# Saved segmented characters for image 247 with label 'GG0327936'
# Saved segmented characters for image 248 with label 'IS2766128'
# Saved segmented characters for image 249 with label 'HT1660489'
# Saved segmented characters for image 250 with label 'IU9496682'
# Saved segmented characters for image 251 with label 'HT5425699'
# Saved segmented characters for image 252 with label 'HV4880569'
# Saved segmented characters for image 254 with label 'IB0419928'
# Saved segmented characters for image 255 with label 'GO8543727'
# Saved segmented characters for image 256 with label 'GV8594892'
# Saved segmented characters for image 257 with label 'HU8923384'
# Saved segmented characters for image 258 with label 'JM6584998'
# Saved segmented characters for image 259 with label 'IQ0472306'
# Saved segmented characters for image 260 with label 'IM4404477'
# Saved segmented characters for image 261 with label 'HT1309492'
# Saved segmented characters for image 262 with label 'JB5396982'
# Saved segmented characters for image 263 with label 'GJ7805243'
# Saved segmented characters for image 264 with label 'GM8223766'
# Saved segmented characters for image 265 with label 'HM1577973'
# Saved segmented characters for image 266 with label 'IP5542649'
# Saved segmented characters for image 267 with label 'IS1214028'
# Saved segmented characters for image 268 with label 'HF0250647'
# Saved segmented characters for image 269 with label 'HC5230168'
# Saved segmented characters for image 270 with label 'ID9040200'
# Saved segmented characters for image 271 with label 'IH0702383'
# Saved segmented characters for image 272 with label 'HO2968060'
# Saved segmented characters for image 273 with label 'GI7837283'
# Saved segmented characters for image 274 with label 'HB5241871'
# Saved segmented characters for image 275 with label 'IC8663223'
# Saved segmented characters for image 276 with label 'IU0503884'
# Saved segmented characters for image 277 with label 'IB6283695'
# Saved segmented characters for image 278 with label 'GV7598222'
# Saved segmented characters for image 279 with label 'IV5756635'
# Saved segmented characters for image 280 with label 'JJ8677493'
# Saved segmented characters for image 281 with label 'IL5550059'
# Saved segmented characters for image 282 with label 'JD4586179'
# Saved segmented characters for image 283 with label 'GM8092636'
# Saved segmented characters for image 284 with label 'IT2652664'
# Saved segmented characters for image 285 with label 'HP0591926'
# Saved segmented characters for image 286 with label 'IG3965032'
# Saved segmented characters for image 287 with label 'GD7686424'
# Saved segmented characters for image 288 with label 'JJ1882155'
# Saved segmented characters for image 289 with label 'GH2084896'
# Saved segmented characters for image 290 with label 'JO0192645'
# Saved segmented characters for image 291 with label 'IX4024740'
# Saved segmented characters for image 292 with label 'IP5510994'
# Saved segmented characters for image 293 with label 'GI5799750'
# Saved segmented characters for image 294 with label 'JA5790758'
# Saved segmented characters for image 295 with label 'IU0210964'
# Saved segmented characters for image 296 with label 'IX6746105'
# Saved segmented characters for image 297 with label 'IY7445026'
# Saved segmented characters for image 298 with label 'JB5008452'
# Saved segmented characters for image 299 with label 'JD4461980'
# Saved segmented characters for image 300 with label 'IY0046268'
# Saved segmented characters for image 302 with label 'IJ4051045'
# Saved segmented characters for image 303 with label 'IX3212285'
# Saved segmented characters for image 304 with label 'HY7308146'
# Saved segmented characters for image 305 with label 'JL4159056'
# Saved segmented characters for image 306 with label 'JE9304342'
# Saved segmented characters for image 307 with label 'JD1715466'
# Saved segmented characters for image 308 with label 'IC4767181'
# Saved segmented characters for image 309 with label 'HP1759723'
# Saved segmented characters for image 310 with label 'JG3652414'
# Saved segmented characters for image 311 with label 'IX7862493'
# Saved segmented characters for image 312 with label 'GV0503524'
# Saved segmented characters for image 313 with label 'JD4397373'
# Saved segmented characters for image 314 with label 'IK3287208'
# Saved segmented characters for image 315 with label 'JI8688559'
# Saved segmented characters for image 316 with label 'IK3170052'
# Saved segmented characters for image 317 with label 'IP0925995'
# Saved segmented characters for image 318 with label 'HM5517416'
# Saved segmented characters for image 319 with label 'GI7397545'
# Saved segmented characters for image 320 with label 'HY7074676'
# Saved segmented characters for image 321 with label 'HP0487375'
# Saved segmented characters for image 322 with label 'HI0852404'
# Saved segmented characters for image 323 with label 'HZ4858793'
# Saved segmented characters for image 324 with label 'GV4739637'
# Saved segmented characters for image 325 with label 'IW9481172'
# Saved segmented characters for image 326 with label 'HV1902972'
# Saved segmented characters for image 327 with label 'IB5460877'
# Saved segmented characters for image 328 with label 'GO4513517'
# Saved segmented characters for image 329 with label 'GU6769839'
# Saved segmented characters for image 330 with label 'GW6804305'
# Saved segmented characters for image 331 with label 'HY3475655'
# Saved segmented characters for image 332 with label 'GM4349350'
# Saved segmented characters for image 333 with label 'GD7686424'
# Saved segmented characters for image 334 with label 'IK3012936'
# Saved segmented characters for image 336 with label 'HS8483394'
# Saved segmented characters for image 337 with label 'HZ5735170'
# Saved segmented characters for image 338 with label 'IL1333469'
# Saved segmented characters for image 339 with label 'HP1759723'
# Saved segmented characters for image 340 with label 'HC7000277'
# Saved segmented characters for image 341 with label 'ID6241257'
# Saved segmented characters for image 342 with label 'JJ7226139'
# Saved segmented characters for image 343 with label 'II3516913'
# Saved segmented characters for image 344 with label 'HJ1659964'
# Saved segmented characters for image 345 with label 'JN0900115'
# Saved segmented characters for image 346 with label 'HD2478036'
# Saved segmented characters for image 347 with label 'GY0959823'
# Saved segmented characters for image 348 with label 'GM7882722'
# Saved segmented characters for image 349 with label 'JF9291782'
# Saved segmented characters for image 350 with label 'IM7838497'
# Saved segmented characters for image 351 with label 'IT5901497'
# Saved segmented characters for image 352 with label 'HC6297892'
# Saved segmented characters for image 353 with label 'HN4933117'
# Saved segmented characters for image 354 with label 'HK1649537'
# Saved segmented characters for image 355 with label 'IK3406838'
# Saved segmented characters for image 356 with label 'GG6973906'
# Saved segmented characters for image 357 with label 'GQ3403758'
# Saved segmented characters for image 358 with label 'HZ5169320'
# Saved segmented characters for image 359 with label 'GZ1468837'
# Saved segmented characters for image 360 with label 'GU6781565'
# Saved segmented characters for image 361 with label 'IU2797218'
# Saved segmented characters for image 362 with label 'GF6641846'
# Saved segmented characters for image 363 with label 'HY2643000'
# Saved segmented characters for image 364 with label 'IT5588474'
# Saved segmented characters for image 365 with label 'JI7113162'
# Saved segmented characters for image 366 with label 'JG7050605'
# Saved segmented characters for image 367 with label 'IH7148108'
# Saved segmented characters for image 368 with label 'GH1123725'
# Saved segmented characters for image 369 with label 'IM6760241'
# Saved segmented characters for image 370 with label 'GI2909265'
# Saved segmented characters for image 371 with label 'II5470839'
# Saved segmented characters for image 372 with label 'JA9223377'
# Saved segmented characters for image 373 with label 'GU9289231'
# Saved segmented characters for image 374 with label 'IH0162965'
# Saved segmented characters for image 375 with label 'IK0361983'
# Saved segmented characters for image 376 with label 'ID5675600'
# Saved segmented characters for image 377 with label 'HN6170918'
# Saved segmented characters for image 378 with label 'HH5314964'
# Saved segmented characters for image 379 with label 'JE8154193'
# Saved segmented characters for image 380 with label 'IH6733936'
# Saved segmented characters for image 381 with label 'HI6433148'
# Saved segmented characters for image 382 with label 'GY8355252'
# Saved segmented characters for image 383 with label 'HN1123296'
# Saved segmented characters for image 384 with label 'GP8328408'
# Saved segmented characters for image 385 with label 'IX8186097'
# Saved segmented characters for image 387 with label 'HW3214591'
# Saved segmented characters for image 388 with label 'JF0735687'
# Saved segmented characters for image 389 with label 'IX7807539'
# Saved segmented characters for image 390 with label 'JF9291782'
# Saved segmented characters for image 391 with label 'IA5179749'
# Saved segmented characters for image 392 with label 'JG3607016'
# Saved segmented characters for image 393 with label 'IG2392857'
# Saved segmented characters for image 394 with label 'JG3898555'
# Saved segmented characters for image 395 with label 'JG3584599'
# Saved segmented characters for image 396 with label 'GO1362446'
# Saved segmented characters for image 397 with label 'JC7644703'
# Saved segmented characters for image 398 with label 'IB7529857'
# Saved segmented characters for image 399 with label 'JA1972123'
# Saved segmented characters for image 400 with label 'ID1273596'
# Saved segmented characters for image 401 with label 'IX8797912'
# Saved segmented characters for image 402 with label 'HQ7925383'
# Saved segmented characters for image 403 with label 'IH3732084'
# Saved segmented characters for image 404 with label 'IF2792690'
# Saved segmented characters for image 405 with label 'GQ3018295'
# Saved segmented characters for image 406 with label 'GS3895492'
# Saved segmented characters for image 407 with label 'IS7216071'
# Saved segmented characters for image 408 with label 'IU0101664'
# Saved segmented characters for image 409 with label 'JI8514816'
# Saved segmented characters for image 410 with label 'HO4440319'
# Saved segmented characters for image 411 with label 'GP5575553'
# Saved segmented characters for image 412 with label 'HO6124392'
# Saved segmented characters for image 413 with label 'IU8912439'
# Saved segmented characters for image 414 with label 'JF0847016'
# Saved segmented characters for image 415 with label 'IN5460336'
# Saved segmented characters for image 416 with label 'IK0521752'
# Saved segmented characters for image 417 with label 'JG3485946'
# Saved segmented characters for image 418 with label 'JA6432273'
# Saved segmented characters for image 419 with label 'ID8222500'
# Saved segmented characters for image 420 with label 'ID8283169'
# Saved segmented characters for image 421 with label 'JG3178987'
# Saved segmented characters for image 422 with label 'JC5672533'
# Saved segmented characters for image 423 with label 'HJ6647731'
# Saved segmented characters for image 424 with label 'GH5954194'
# Saved segmented characters for image 425 with label 'JF9292055'
# Saved segmented characters for image 426 with label 'HW4828229'
# Saved segmented characters for image 427 with label 'JE9425702'
# Saved segmented characters for image 428 with label 'IR8471678'
# Saved segmented characters for image 429 with label 'JB1437962'
# Saved segmented characters for image 430 with label 'IZ5305950'
# Saved segmented characters for image 431 with label 'IF2929920'
# Saved segmented characters for image 432 with label 'IQ0225041'
# Saved segmented characters for image 433 with label 'GX4239984'
# Saved segmented characters for image 434 with label 'HX8889571'
# Saved segmented characters for image 435 with label 'GF0329951'
# Saved segmented characters for image 436 with label 'JK2104103'
# Saved segmented characters for image 437 with label 'HB7862487'
# Saved segmented characters for image 438 with label 'IT5503420'
# Saved segmented characters for image 439 with label 'IH0453045'
# Saved segmented characters for image 440 with label 'JM6707917'
# Saved segmented characters for image 441 with label 'GZ1853507'
# Saved segmented characters for image 442 with label 'JI6892600'
# Saved segmented characters for image 443 with label 'GT2539839'
# Saved segmented characters for image 444 with label 'GV3384188'
# Saved segmented characters for image 445 with label 'HJ6671572'
# Saved segmented characters for image 446 with label 'HX4449072'
# Saved segmented characters for image 447 with label 'IS7133158'
# Saved segmented characters for image 448 with label 'IW5393859'
# Saved segmented characters for image 449 with label 'JA3518277'
# Saved segmented characters for image 450 with label 'JD1600131'
# Saved segmented characters for image 451 with label 'GT4829981'
# Saved segmented characters for image 452 with label 'GL9474489'
# Saved segmented characters for image 453 with label 'HO5224974'
# Saved segmented characters for image 454 with label 'GZ6536621'
# Saved segmented characters for image 455 with label 'IP5650430'
# Saved segmented characters for image 456 with label 'IZ3318750'
# Saved segmented characters for image 457 with label 'JJ6853505'
# Saved segmented characters for image 458 with label 'ID2288074'
# Saved segmented characters for image 459 with label 'HB2327121'
# Saved segmented characters for image 460 with label 'HB1160312'
# Saved segmented characters for image 461 with label 'HB5074196'
# Saved segmented characters for image 462 with label 'HY7138112'
# Saved segmented characters for image 463 with label 'HY1326018'
# Saved segmented characters for image 464 with label 'JF0481496'
# Saved segmented characters for image 465 with label 'IT0014071'
# Saved segmented characters for image 466 with label 'HX1189818'
# Saved segmented characters for image 467 with label 'IT6022463'
# Saved segmented characters for image 468 with label 'GS3167548'
# Saved segmented characters for image 469 with label 'GP0054640'
# Saved segmented characters for image 470 with label 'HX1955196'
# Saved segmented characters for image 471 with label 'IW9202120'
# Saved segmented characters for image 472 with label 'JA6760996'
# Saved segmented characters for image 473 with label 'JA6190375'
# Saved segmented characters for image 474 with label 'HA5391184'
# Saved segmented characters for image 475 with label 'HT0913940'
# Saved segmented characters for image 476 with label 'GZ8693434'
# Saved segmented characters for image 477 with label '1U8765705'
# Saved segmented characters for image 478 with label 'JB5695830'
# Saved segmented characters for image 479 with label 'JB7818495'
# Saved segmented characters for image 480 with label 'IS4927411'
# Saved segmented characters for image 481 with label 'JC2789582'
# Saved segmented characters for image 482 with label 'II2636106'
# Saved segmented characters for image 483 with label 'JA2604904'
# Saved segmented characters for image 484 with label 'GZ6536621'
# Saved segmented characters for image 485 with label 'IO9009378'
# Saved segmented characters for image 486 with label 'IA2311906'
# Saved segmented characters for image 487 with label 'GM1752694'
# Saved segmented characters for image 488 with label 'HQ0818363'
# Saved segmented characters for image 489 with label 'JJ1764374'
# Saved segmented characters for image 490 with label 'GP0522408'
# Saved segmented characters for image 491 with label 'HI5829724'
# Saved segmented characters for image 492 with label 'GO1362446'
# Saved segmented characters for image 493 with label 'GF0413577'
# Saved segmented characters for image 494 with label 'IL6669538'
# Saved segmented characters for image 495 with label 'ID5418533'
# Saved segmented characters for image 496 with label 'HN4260884'
# Saved segmented characters for image 497 with label 'IU8972893'
# Saved segmented characters for image 498 with label 'IC2920980'
# Saved segmented characters for image 499 with label 'JC2461639'
# Saved segmented characters for image 500 with label 'IS5078062'
# Saved segmented characters for image 501 with label 'HQ7728748'
# Saved segmented characters for image 502 with label 'JH3909342'
# Saved segmented characters for image 503 with label 'EU6852221'
# Saved segmented characters for image 504 with label 'GF0413577'
# Saved segmented characters for image 505 with label 'IR8058833'
# Saved segmented characters for image 506 with label 'IV0494024'
# Saved segmented characters for image 507 with label 'HZ5326756'
# Saved segmented characters for image 508 with label 'IP6899449'
# Saved segmented characters for image 509 with label 'JA0978306'
# Saved segmented characters for image 510 with label 'HE3055635'
# Saved segmented characters for image 511 with label 'GX0651423'
# Saved segmented characters for image 512 with label 'II3856259'
# Saved segmented characters for image 513 with label 'IR5357254'
# Saved segmented characters for image 514 with label 'GR1895691'
# Saved segmented characters for image 515 with label 'GO1035465'
# Saved segmented characters for image 516 with label 'JF3016440'
# Saved segmented characters for image 517 with label 'HQ5226707'
# Saved segmented characters for image 518 with label 'IV6218589'
# Saved segmented characters for image 519 with label 'HV5258855'
# Saved segmented characters for image 520 with label 'IS1214028'
# Saved segmented characters for image 521 with label 'JA8822351'
# Saved segmented characters for image 522 with label 'HQ3995335'
# Saved segmented characters for image 523 with label 'HK7074988'
# Saved segmented characters for image 524 with label 'HT5583061'
# Saved segmented characters for image 525 with label 'IE8850036'
# Saved segmented characters for image 526 with label 'IZ4140334'
# Saved segmented characters for image 527 with label 'GR7687951'
# Saved segmented characters for image 528 with label 'IV6124361'
# Saved segmented characters for image 529 with label 'HQ7945185'
# Saved segmented characters for image 530 with label 'HQ2422322'
# Saved segmented characters for image 531 with label 'HY3475655'
# Saved segmented characters for image 532 with label 'HL2327325'
# Saved segmented characters for image 533 with label 'HT1185278'
# Saved segmented characters for image 534 with label 'IB8245697'
# Saved segmented characters for image 535 with label 'HI2872596'
# Saved segmented characters for image 536 with label 'HV6357661'
# Saved segmented characters for image 537 with label 'JM2254350'
# Saved segmented characters for image 538 with label 'IB7548920'
# Saved segmented characters for image 539 with label 'IA0958345'
# Saved segmented characters for image 540 with label 'GC0100319'
# Saved segmented characters for image 541 with label 'ID3202554'
# Saved segmented characters for image 542 with label 'HQ4646085'
# Saved segmented characters for image 543 with label 'JI6303612'
# Saved segmented characters for image 544 with label 'HN6795089'
# Saved segmented characters for image 545 with label 'HD7282568'
# Saved segmented characters for image 546 with label 'JL4220026'
# Saved segmented characters for image 547 with label 'HO4440319'
# Saved segmented characters for image 548 with label 'GL7437336'
# Saved segmented characters for image 549 with label 'IJ8859645'
# Saved segmented characters for image 550 with label 'IO2414937'
# Saved segmented characters for image 551 with label 'HZ3970836'
# Saved segmented characters for image 552 with label 'IX4539714'
# Saved segmented characters for image 553 with label 'IH5354743'
# Saved segmented characters for image 554 with label 'FY7579452'
# Saved segmented characters for image 555 with label 'HF2382647'
# Saved segmented characters for image 556 with label 'JI7092061'
# Saved segmented characters for image 557 with label 'IU8972893'
# Saved segmented characters for image 558 with label 'JA3844325'
# Saved segmented characters for image 559 with label 'GM8092636'
# Saved segmented characters for image 560 with label 'HC2311992'
# Saved segmented characters for image 561 with label 'JH8471785'
# Saved segmented characters for image 562 with label 'IJ4498327'
# Saved segmented characters for image 563 with label 'IS4927411'
# Saved segmented characters for image 564 with label 'JD1135415'
# Saved segmented characters for image 565 with label 'HZ3083871'
# Saved segmented characters for image 566 with label 'HF7261897'
# Saved segmented characters for image 567 with label 'HW5109763'
# Saved segmented characters for image 568 with label 'HR2425690'
# Saved segmented characters for image 569 with label 'HK1834355'
# Saved segmented characters for image 570 with label 'GS2083953'
# Saved segmented characters for image 571 with label 'GY6869621'
# Saved segmented characters for image 572 with label 'JH1328712'
# Saved segmented characters for image 573 with label 'GQ0169787'
# Saved segmented characters for image 574 with label 'GE4173449'
# Saved segmented characters for image 575 with label 'HA8128383'
# Saved segmented characters for image 576 with label 'IC2920980'
# Saved segmented characters for image 577 with label 'JH7512690'
# Saved segmented characters for image 578 with label 'JJ7393118'
# Saved segmented characters for image 579 with label 'IM2176561'
# Saved segmented characters for image 580 with label 'IF7929080'
# Saved segmented characters for image 581 with label 'HC7501655'
# Saved segmented characters for image 582 with label 'IC0234481'
# Saved segmented characters for image 583 with label 'IZ1556642'
# Saved segmented characters for image 584 with label 'JJ7389616'
# Saved segmented characters for image 586 with label 'HT5425699'
# Saved segmented characters for image 587 with label 'IE9287947'
# Saved segmented characters for image 588 with label 'GJ3228576'
# Saved segmented characters for image 590 with label 'GH1972990'
# Saved segmented characters for image 591 with label 'GJ7805243'
# Saved segmented characters for image 592 with label 'JE1055077'
# Saved segmented characters for image 593 with label 'HK1203890'
# Saved segmented characters for image 594 with label 'HH2522542'
# Saved segmented characters for image 595 with label 'IM2176561'
# Saved segmented characters for image 596 with label 'JG2497296'
# Saved segmented characters for image 597 with label 'IC3560008'
# Saved segmented characters for image 598 with label 'HQ7850474'
# Saved segmented characters for image 600 with label 'IK0757968'
# Saved segmented characters for image 601 with label 'HI5902786'
# Saved segmented characters for image 602 with label 'IS0651888'
# Saved segmented characters for image 603 with label 'HE2552238'
# Saved segmented characters for image 604 with label 'GO7988514'
# Saved segmented characters for image 605 with label 'IY3314753'
# Saved segmented characters for image 606 with label 'IY7871414'
# Saved segmented characters for image 607 with label 'IX4217090'
# Saved segmented characters for image 608 with label 'IJ3399715'
# Saved segmented characters for image 609 with label 'IE3732580'
# Saved segmented characters for image 610 with label 'GX3611068'
# Saved segmented characters for image 611 with label 'IT6022463'
# Saved segmented characters for image 612 with label 'HO5135887'
# Saved segmented characters for image 613 with label 'IZ6964468'
# Saved segmented characters for image 614 with label 'JQ0483640'
# Saved segmented characters for image 615 with label 'GR8112757'
# Saved segmented characters for image 617 with label 'ID9130712'
# Saved segmented characters for image 618 with label 'IY7445026'
# Saved segmented characters for image 619 with label 'JI0725926'
# Saved segmented characters for image 620 with label 'IR8058833'
# Saved segmented characters for image 621 with label 'IM4633437'
# Saved segmented characters for image 622 with label 'GP0522408'
# Saved segmented characters for image 623 with label 'IZ4552234'
# Saved segmented characters for image 624 with label 'HD8851040'
# Saved segmented characters for image 626 with label 'IH0225992'
# Saved segmented characters for image 627 with label 'IQ6664486'
# Saved segmented characters for image 628 with label 'GM3046614'
# Saved segmented characters for image 629 with label 'ID1860107'
# Saved segmented characters for image 630 with label 'JD2696287'
# Saved segmented characters for image 631 with label 'IL1333469'
# Saved segmented characters for image 632 with label 'GH8695649'
# Saved segmented characters for image 633 with label 'HS6695046'
# Saved segmented characters for image 634 with label 'JI7092061'
# Saved segmented characters for image 635 with label 'JA6435519'
# Saved segmented characters for image 636 with label 'JC4459678'
# Saved segmented characters for image 637 with label 'IT5901497'
# Saved segmented characters for image 638 with label 'HD2755054'
# Saved segmented characters for image 639 with label 'HJ5358157'
# Saved segmented characters for image 640 with label 'JI0029154'
# Saved segmented characters for image 641 with label 'HQ7781765'
# Saved segmented characters for image 642 with label 'IZ6723652'
# Saved segmented characters for image 643 with label 'JH1399390'
# Saved segmented characters for image 644 with label 'IM1883077'
# Saved segmented characters for image 645 with label 'GO2174105'
# Saved segmented characters for image 646 with label 'HW3363369'
# Saved segmented characters for image 647 with label 'HY5976268'
# Saved segmented characters for image 648 with label 'HM5743606'
# Saved segmented characters for image 649 with label 'JL8822024'
# Saved segmented characters for image 650 with label 'HT9123360'
# Saved segmented characters for image 651 with label 'HC7677549'
# Saved segmented characters for image 652 with label 'IZ4184851'
# Saved segmented characters for image 653 with label 'GQ7105698'
# Saved segmented characters for image 654 with label 'IT8863820'
# Saved segmented characters for image 655 with label 'HL2104144'
# Saved segmented characters for image 657 with label 'IR3103453'
# Saved segmented characters for image 658 with label 'IM7269974'
# Saved segmented characters for image 660 with label 'HM1441719'
# Saved segmented characters for image 661 with label 'IA6629025'
# Saved segmented characters for image 662 with label 'JI7706384'
# Saved segmented characters for image 663 with label 'IK0942058'
# Saved segmented characters for image 664 with label 'IC0222839'
# Saved segmented characters for image 665 with label 'HZ3303205'
# Saved segmented characters for image 666 with label 'HJ6671572'
# Saved segmented characters for image 667 with label 'HM5743606'
# Saved segmented characters for image 668 with label 'IS8268765'
# Saved segmented characters for image 669 with label 'IU4286693'
# Saved segmented characters for image 670 with label 'IG9302297'
# Saved segmented characters for image 671 with label 'HO6112119'
# Saved segmented characters for image 672 with label 'IB0914821'
# Saved segmented characters for image 673 with label 'GT3434715'
# Saved segmented characters for image 674 with label 'IU8765705'
# Saved segmented characters for image 675 with label 'GY8355252'
# Saved segmented characters for image 676 with label 'GL6195246'
# Saved segmented characters for image 677 with label 'HC7501655'
# Saved segmented characters for image 678 with label 'HT8638391'
# Saved segmented characters for image 679 with label 'JB1211636'
# Saved segmented characters for image 680 with label 'HK6989991'
# Saved segmented characters for image 681 with label 'IT2652664'
# Saved segmented characters for image 682 with label 'JI6874253'
# Saved segmented characters for image 683 with label 'GX2540880'
# Saved segmented characters for image 684 with label 'HY7138112'
# Saved segmented characters for image 685 with label 'IW3568190'
# Saved segmented characters for image 686 with label 'GH9045038'
# Saved segmented characters for image 687 with label 'IX4024740'
# Saved segmented characters for image 688 with label 'JJ6853505'
# Saved segmented characters for image 689 with label 'HR6339555'
# Saved segmented characters for image 690 with label 'GM1074059'
# Saved segmented characters for image 691 with label 'JI7443272'
# Saved segmented characters for image 692 with label 'JJ9108428'
# Saved segmented characters for image 693 with label 'IV0684643'
# Saved segmented characters for image 694 with label 'JF4947237'
# Saved segmented characters for image 695 with label 'JG3803061'
# Saved segmented characters for image 697 with label 'GU0888822'
# Saved segmented characters for image 698 with label 'IW3352760'
# Saved segmented characters for image 699 with label 'HD8844079'
# Saved segmented characters for image 700 with label 'IK4996983'
# Saved segmented characters for image 701 with label 'JI0991286'
# Saved segmented characters for image 702 with label 'HB2466938'
# Saved segmented characters for image 703 with label 'GI3600629'
# Saved segmented characters for image 705 with label 'GV9385703'
# Saved segmented characters for image 706 with label 'ID3129372'
# Saved segmented characters for image 707 with label 'HX9306787'
# Saved segmented characters for image 708 with label 'IK3012936'
# Saved segmented characters for image 709 with label 'HY2497681'
# Saved segmented characters for image 710 with label 'IN1144481'
# Saved segmented characters for image 711 with label 'IX6240654'
# Saved segmented characters for image 712 with label 'HH9342334'
# Saved segmented characters for image 713 with label 'HM6217665'
# Saved segmented characters for image 714 with label 'JA5131694'
# Saved segmented characters for image 715 with label 'IY7625244'
# Saved segmented characters for image 716 with label 'IW9481172'
# Saved segmented characters for image 717 with label 'IV7579645'
# Saved segmented characters for image 718 with label 'JD3425363'
# Saved segmented characters for image 719 with label 'HQ4214484'
# Saved segmented characters for image 720 with label 'JA3506146'
# Saved segmented characters for image 721 with label 'JI1370660'
# Saved segmented characters for image 722 with label 'GD5652568'
# Saved segmented characters for image 723 with label 'IH7207830'
# Saved segmented characters for image 724 with label 'IN3096797'
# Saved segmented characters for image 725 with label 'GQ7105698'
# Saved segmented characters for image 726 with label 'HY5066152'
# Saved segmented characters for image 727 with label 'HO6545698'
# Saved segmented characters for image 728 with label 'HR7199673'
# Saved segmented characters for image 729 with label 'JG2418905'
# Saved segmented characters for image 730 with label 'HU8923384'
# Saved segmented characters for image 731 with label 'IL6669538'
# Saved segmented characters for image 732 with label 'IQ7757400'
# Saved segmented characters for image 733 with label 'HB6956358'
# Saved segmented characters for image 734 with label 'II5470839'
# Saved segmented characters for image 735 with label 'GK7707500'
# Saved segmented characters for image 736 with label 'HL2104144'
# Saved segmented characters for image 737 with label 'IF2792690'
# Saved segmented characters for image 738 with label 'IK3717299'
# Saved segmented characters for image 739 with label 'IU8790877'
# Saved segmented characters for image 740 with label 'IH0453045'
# Saved segmented characters for image 741 with label 'JJ8443292'
# Saved segmented characters for image 742 with label 'JA0297577'
# Saved segmented characters for image 743 with label 'HB5620267'
# Saved segmented characters for image 744 with label 'JP1217155'
# Saved segmented characters for image 745 with label 'IR8105887'
# Saved segmented characters for image 746 with label 'HQ8199338'
# Saved segmented characters for image 747 with label 'IT8904765'
# Saved segmented characters for image 748 with label 'HE7951269'
# Saved segmented characters for image 749 with label 'HG6026199'
# Saved segmented characters for image 750 with label 'IY2853884'
# Saved segmented characters for image 751 with label 'IB0914821'
# Saved segmented characters for image 752 with label 'IB8096356'
# Saved segmented characters for image 753 with label 'IY7885275'
# Saved segmented characters for image 754 with label 'HO6670725'
# Saved segmented characters for image 755 with label 'IF3800136'
# Saved segmented characters for image 756 with label 'GX9262596'
# Saved segmented characters for image 757 with label 'IC8002442'
# Saved segmented characters for image 758 with label 'GF2594597'
# Saved segmented characters for image 759 with label 'JF0463450'
# Saved segmented characters for image 760 with label 'HV6357661'
# Saved segmented characters for image 761 with label 'IW5588800'
# Saved segmented characters for image 762 with label 'JI6778519'
# Saved segmented characters for image 763 with label 'GU0127073'
# Saved segmented characters for image 764 with label 'HI6447909'
# Saved segmented characters for image 765 with label 'IJ8859645'
# Saved segmented characters for image 766 with label 'HG8988084'
# Saved segmented characters for image 767 with label 'HL1483833'
# ...
# Saved segmented characters for image 83 with label 'GP0054640'
# Saved segmented characters for image 84 with label 'GV5712635'
# Saved segmented characters for image 85 with label 'IC0234481'
# Saved segmented characters for image 86 with label 'GR7820811'
# Saved segmented characters for image 87 with label 'IZ5766627'
# Saved segmented characters for image 88 with label 'GQ2538363'
# Saved segmented characters for image 89 with label 'IM4380027'
# Saved segmented characters for image 90 with label 'IE3732580'
# Saved segmented characters for image 91 with label 'GG7973020'
# Saved segmented characters for image 92 with label 'IP5378569'
# Saved segmented characters for image 93 with label 'HR4465063'
# Saved segmented characters for image 94 with label 'II2654472'
# Saved segmented characters for image 95 with label 'IU8790877'
# Saved segmented characters for image 96 with label 'JC2962978'
# Saved segmented characters for image 97 with label 'IK0521752'
# Saved segmented characters for image 98 with label 'JE1209245'
# Saved segmented characters for image 99 with label 'IX7019554'
# Saved segmented characters for image 100 with label 'JF6911849'
# Saved segmented characters for image 101 with label 'JG3652414'
# Saved segmented characters for image 102 with label 'GJ7958905'
# Saved segmented characters for image 103 with label 'IP5378569'
# Saved segmented characters for image 104 with label 'IR7746852'
# Saved segmented characters for image 105 with label 'IS2766128'
# Saved segmented characters for image 106 with label 'GK7386408'
# Saved segmented characters for image 107 with label 'IT6046573'
# Saved segmented characters for image 108 with label 'IQ0395560'
# Saved segmented characters for image 109 with label 'IO7072710'
# Saved segmented characters for image 110 with label 'IM0170657'
# Saved segmented characters for image 111 with label 'JA6515439'
# Saved segmented characters for image 112 with label 'IK0757968'
# Saved segmented characters for image 113 with label 'GS2561248'
# Saved segmented characters for image 114 with label 'GX0651423'
# Saved segmented characters for image 115 with label 'HT1185278'
# Saved segmented characters for image 116 with label 'JK7576002'
# Saved segmented characters for image 117 with label 'JE1971849'
# Saved segmented characters for image 118 with label 'GL5679426'
# Saved segmented characters for image 119 with label 'JI7608716'
# Saved segmented characters for image 120 with label 'HN4933117'
# Saved segmented characters for image 121 with label 'GH7438089'
# Saved segmented characters for image 122 with label 'IB5461894'
# Saved segmented characters for image 123 with label 'JL4070409'
# Saved segmented characters for image 124 with label 'JG4010150'
# Saved segmented characters for image 125 with label 'GV8594892'
# Saved segmented characters for image 126 with label 'IT0014071'
# Saved segmented characters for image 127 with label 'JE1643731'
# Saved segmented characters for image 128 with label 'HW3731489'
# Saved segmented characters for image 129 with label 'HZ4886570'
# Saved segmented characters for image 130 with label 'GQ7453168'
# Saved segmented characters for image 131 with label 'JE1343358'
# Saved segmented characters for image 132 with label 'IS8558501'
# Saved segmented characters for image 133 with label 'JH9416673'
# Saved segmented characters for image 134 with label 'IW2119537'
# Saved segmented characters for image 135 with label 'IQ0337328'
# Saved segmented characters for image 136 with label 'IG7252785'
# Saved segmented characters for image 137 with label 'HL1871577'
# Saved segmented characters for image 138 with label 'GL7565288'
# Saved segmented characters for image 139 with label 'IZ6723652'
# Saved segmented characters for image 140 with label 'IZ1556642'
# Saved segmented characters for image 141 with label 'IA6570516'
# Saved segmented characters for image 142 with label 'IF8265763'
# Saved segmented characters for image 143 with label 'IE3061482'
# Saved segmented characters for image 144 with label 'IK4996983'
# Saved segmented characters for image 145 with label 'IC3034642'
# Saved segmented characters for image 146 with label 'HW0880173'
# Saved segmented characters for image 147 with label 'GR7687951'
# Saved segmented characters for image 148 with label 'IH1456243'
# Saved segmented characters for image 149 with label 'JA3627959'
# Saved segmented characters for image 150 with label 'HW3450959'
# Saved segmented characters for image 151 with label 'GG9347326'
# Saved segmented characters for image 152 with label 'II8298308'
# Saved segmented characters for image 153 with label 'IR5963828'
# Saved segmented characters for image 154 with label 'JB6888453'
# Saved segmented characters for image 155 with label 'HN1780303'
# Saved segmented characters for image 156 with label 'IA6570516'
# Saved segmented characters for image 157 with label 'JE9138435'
# Saved segmented characters for image 159 with label 'IF3367864'
# Saved segmented characters for image 160 with label 'HA1067173'
# Saved segmented characters for image 161 with label 'JJ8129194'
# Saved segmented characters for image 162 with label 'GW6562782'
# Saved segmented characters for image 163 with label 'IS8668776'
# Saved segmented characters for image 164 with label 'IC5366536'
# Saved segmented characters for image 165 with label 'IR2354397'
# Saved segmented characters for image 166 with label 'HT7393156'
# Saved segmented characters for image 167 with label 'HM5801955'
# Saved segmented characters for image 168 with label 'IP5253273'
# Saved segmented characters for image 169 with label 'IG9271915'
# Saved segmented characters for image 170 with label 'HR6339555'
# Saved segmented characters for image 171 with label 'IS8268765'
# Saved segmented characters for image 172 with label 'GE5442674'
# Saved segmented characters for image 173 with label 'IX6776829'
# Saved segmented characters for image 174 with label 'GI3600629'
# Saved segmented characters for image 175 with label 'HY3976554'
# Saved segmented characters for image 177 with label 'GY7207125'
# Saved segmented characters for image 178 with label 'JJ1764374'
# Saved segmented characters for image 179 with label 'JJ7846519'
# Saved segmented characters for image 180 with label 'HZ3561836'
# Saved segmented characters for image 181 with label 'GE5664647'
# Saved segmented characters for image 182 with label 'HL1871577'
# Saved segmented characters for image 183 with label 'HX9305207'
# Saved segmented characters for image 184 with label 'HK7293767'
# Saved segmented characters for image 185 with label 'IL8312715'
# Saved segmented characters for image 186 with label 'IS5078062'
# Saved segmented characters for image 187 with label 'IR3103453'
# Saved segmented characters for image 188 with label 'GJ3004912'
# Saved segmented characters for image 189 with label 'IE8850036'
# Saved segmented characters for image 190 with label 'JJ3056732'
# Saved segmented characters for image 191 with label 'II8952422'
# Saved segmented characters for image 192 with label 'HM1346351'
# Saved segmented characters for image 193 with label 'HS0706079'
# Saved segmented characters for image 195 with label 'II9284218'
# Saved segmented characters for image 196 with label 'JG5914417'
# Saved segmented characters for image 197 with label 'ID5554156'
# Saved segmented characters for image 198 with label 'IR2354397'
# Saved segmented characters for image 199 with label 'IU0101664'
# Saved segmented characters for image 200 with label 'HQ3868442'
# Saved segmented characters for image 201 with label 'HC2311992'
# Saved segmented characters for image 202 with label 'JB7818495'
# Saved segmented characters for image 203 with label 'HK4190421'
# Saved segmented characters for image 204 with label 'GO8543727'
# Saved segmented characters for image 205 with label 'GG7973020'
# Saved segmented characters for image 206 with label 'HY3314536'
# Saved segmented characters for image 207 with label 'GV7962348'
# Saved segmented characters for image 208 with label 'HC5002950'
# Saved segmented characters for image 209 with label 'HQ7111144'
# Saved segmented characters for image 210 with label 'JE9304342'
# Saved segmented characters for image 211 with label 'IL5619503'
# Saved segmented characters for image 212 with label 'IF8362628'
# Saved segmented characters for image 213 with label 'IQ2799179'
# Saved segmented characters for image 214 with label 'IH7371214'
# Saved segmented characters for image 215 with label 'IW9202120'
# Saved segmented characters for image 216 with label 'GI6670348'
# Saved segmented characters for image 217 with label 'HY7308146'
# Saved segmented characters for image 218 with label 'HX5303476'
# Saved segmented characters for image 219 with label 'HD2775775'
# Saved segmented characters for image 220 with label 'HP2579603'
# Saved segmented characters for image 221 with label 'IU7630295'
# Saved segmented characters for image 222 with label 'JD3109962'
# Saved segmented characters for image 223 with label 'HH2814720'
# Saved segmented characters for image 224 with label 'IN1814889'
# Saved segmented characters for image 225 with label 'IR8179002'
# Saved segmented characters for image 226 with label 'IY3421433'
# Saved segmented characters for image 227 with label 'GD5652568'
# Saved segmented characters for image 228 with label 'II5215298'
# Saved segmented characters for image 229 with label 'IQ3039568'
# Saved segmented characters for image 230 with label 'IT9361060'
# Saved segmented characters for image 231 with label 'GT0030707'
# Saved segmented characters for image 232 with label 'HU0962002'
# Saved segmented characters for image 233 with label 'GV7962348'
# Saved segmented characters for image 234 with label 'GQ7453168'
# Saved segmented characters for image 235 with label 'JD3757983'
# Saved segmented characters for image 236 with label 'GF3234531'
# Saved segmented characters for image 237 with label 'GK7332797'
# Saved segmented characters for image 238 with label 'IJ9331566'
# Saved segmented characters for image 239 with label 'IG5780853'
# Saved segmented characters for image 240 with label 'HF7297122'
# Saved segmented characters for image 241 with label 'GJ7834555'
# Saved segmented characters for image 242 with label 'HX8684695'
# Saved segmented characters for image 243 with label 'IM3283080'
# Saved segmented characters for image 244 with label 'HN1351297'
# Saved segmented characters for image 245 with label 'IJ0166198'
# Saved segmented characters for image 246 with label 'GP2372252'
# Saved segmented characters for image 247 with label 'II3856259'
# Saved segmented characters for image 248 with label 'IO9009378'
# Saved segmented characters for image 249 with label 'IS0597261'
# Saved segmented characters for image 251 with label 'IP0565449'
# Saved segmented characters for image 252 with label 'HB6956358'
# Saved segmented characters for image 253 with label 'IP9404141'
# Saved segmented characters for image 254 with label 'HN1351297'
# Saved segmented characters for image 255 with label 'HY2399660'
# Saved segmented characters for image 256 with label 'GX2211629'
# Saved segmented characters for image 257 with label 'IO4333416'
# Saved segmented characters for image 258 with label 'GB3136505'
# Saved segmented characters for image 259 with label 'HE8641431'
# Saved segmented characters for image 260 with label 'JE0843941'
# Saved segmented characters for image 261 with label 'JJ2260305'
# Saved segmented characters for image 262 with label 'IO2397636'
# Saved segmented characters for image 263 with label 'IU8912439'
# Saved segmented characters for image 264 with label 'GK9010020'
# Saved segmented characters for image 265 with label 'JD3109962'
# Saved segmented characters for image 266 with label 'JG6460443'
# Saved segmented characters for image 267 with label 'JA6941872'
# Saved segmented characters for image 268 with label 'HY3297468'
# Saved segmented characters for image 269 with label 'HJ2202389'
# Saved segmented characters for image 270 with label 'HM1181066'
# Saved segmented characters for image 271 with label 'HM1703817'
# Saved segmented characters for image 272 with label 'GK7029635'
# Saved segmented characters for image 273 with label 'IB0419928'
# Saved segmented characters for image 274 with label 'JI6892600'
# Saved segmented characters for image 275 with label 'GZ7014771'
# Saved segmented characters for image 276 with label 'IO9122303'
# Saved segmented characters for image 277 with label 'JJ2278827'
# Saved segmented characters for image 278 with label 'HP3067248'
# Saved segmented characters for image 279 with label 'GY0300050'
# Saved segmented characters for image 280 with label 'IF6669077'
# Saved segmented characters for image 281 with label 'HQ7693815'
# Saved segmented characters for image 282 with label 'IH4147599'
# Saved segmented characters for image 283 with label 'JA6435519'
# Saved segmented characters for image 284 with label 'IN8090372'
# Saved segmented characters for image 285 with label 'GE5442674'
# Saved segmented characters for image 286 with label 'JH8471785'
# Saved segmented characters for image 287 with label 'GQ4952473'
# Saved segmented characters for image 288 with label 'GA1652141'
# Saved segmented characters for image 289 with label 'HT4161679'
# Saved segmented characters for image 291 with label 'IV6218589'
# Saved segmented characters for image 292 with label 'II4529004'
# Saved segmented characters for image 293 with label 'JD2120065'
# Saved segmented characters for image 294 with label 'GU7262401'
# Saved segmented characters for image 295 with label 'HQ3868442'
# Saved segmented characters for image 297 with label 'HX1955196'
# Saved segmented characters for image 298 with label 'IL7908654'
# Saved segmented characters for image 299 with label 'ID5857804'
# Saved segmented characters for image 300 with label 'IW5821275'
# Saved segmented characters for image 301 with label 'IV7579645'
# Saved segmented characters for image 302 with label 'HX4863465'
# Saved segmented characters for image 303 with label 'GF2881372'
# Saved segmented characters for image 304 with label 'GZ1528599'
# Saved segmented characters for image 305 with label 'IL7908654'
# Saved segmented characters for image 306 with label 'JH2732255'
# Saved segmented characters for image 307 with label 'HZ2597458'
# Saved segmented characters for image 308 with label 'IG4043498'
# Saved segmented characters for image 309 with label 'HC4905366'
# Saved segmented characters for image 310 with label 'IC1175190'
# Saved segmented characters for image 311 with label 'IS7216071'
# Saved segmented characters for image 312 with label 'HW0880173'
# Saved segmented characters for image 313 with label 'HO2968060'
# Saved segmented characters for image 314 with label 'HU3458061'
# Saved segmented characters for image 315 with label 'IC8002442'
# Saved segmented characters for image 316 with label 'JN0076465'
# Saved segmented characters for image 317 with label 'IL5275240'
# Saved segmented characters for image 318 with label 'G71770040'
# Saved segmented characters for image 319 with label 'HY5323161'
# Saved segmented characters for image 320 with label 'HA1229562'
# Saved segmented characters for image 321 with label 'JA7409337'
# Saved segmented characters for image 322 with label 'HH0743693'
# Saved segmented characters for image 323 with label 'IM4380027'
# Saved segmented characters for image 325 with label 'IL5619503'
# Saved segmented characters for image 326 with label 'GX3605865'
# Saved segmented characters for image 327 with label 'HH5500990'
# Saved segmented characters for image 328 with label 'IE8850492'
# Saved segmented characters for image 329 with label 'HM1441719'
# Saved segmented characters for image 330 with label 'IG7911163'
# Saved segmented characters for image 331 with label 'HN6795089'
# Saved segmented characters for image 332 with label 'IW9486698'
# Saved segmented characters for image 333 with label 'HQ9459309'
# Saved segmented characters for image 334 with label 'IW3552434'
# Saved segmented characters for image 335 with label 'JE9425702'
# Saved segmented characters for image 336 with label 'IG6183965'
# Saved segmented characters for image 337 with label 'GP5129622'
# Saved segmented characters for image 338 with label 'IT5964281'
# Saved segmented characters for image 339 with label 'JR7717411'
